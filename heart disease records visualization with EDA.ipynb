# %%
import numpy as np # linear algebra
import pandas as pd #data processing, csv file I/O

import os
for dirname, _, filenames in os.walk(r'C:\data analyst course\november'):
    for filename in filenames:
        print(os.path.join(dirname,filename))
# Out:
# C:\data analyst course\november\01-dec -dict\NIT-FSDS 5.30AM_ Course Summarization.xlsx
# C:\data analyst course\november\01-dec -dict\PYTHON DATA STRUCTURE.ipynb
# C:\data analyst course\november\01-dec -dict\REGULAR CLASS NOTES 5.30 AM.txt
# C:\data analyst course\november\01-dec -dict\TUPLE, SET, DICTIONARY.pdf
# C:\data analyst course\november\11th - pil, numpy, plt -\NIT-FSDS 5.30PM_ Course Summarization.xlsx
# C:\data analyst course\november\11th - pil, numpy, plt -\NUMPY, PIL.ipynb
# C:\data analyst course\november\11th - pil, numpy, plt -\REGULAR CLASS NOTES 5.30 AM.txt
# C:\data analyst course\november\12th- Np, Plt\Dataset.txt
# C:\data analyst course\november\12th- Np, Plt\Matrix Visualization.ipynb
# C:\data analyst course\november\13th\REGULAR CLASS NOTES 5.30 AM.txt
# C:\data analyst course\november\14th- Introduction to pandas\NIT-FSDS 5.30PM_ Course Summarization.xlsx
# C:\data analyst course\november\14th- Introduction to pandas\PANDAS 1.ipynb
# C:\data analyst course\november\14th- Introduction to pandas\pandas documentation.pdf
# C:\data analyst course\november\14th- Introduction to pandas\pandas workshop.ipynb
# C:\data analyst course\november\14th- Introduction to pandas\REGULAR CLASS NOTES 5.30 AM.txt
# C:\data analyst course\november\14th- Introduction to pandas\Sample - Superstore_Orders.csv
# C:\data analyst course\november\15 nov\county gdp analysis.pdf
# C:\data analyst course\november\15 nov\data.csv
# C:\data analyst course\november\15 nov\NIT-FSDS 5.30PM_ Course Summarization.xlsx
# C:\data analyst course\november\15 nov\pandas 2.ipynb
# C:\data analyst course\november\15 nov\REGULAR CLASS NOTES 5.30 AM.txt
# C:\data analyst course\november\15th,16th matplotlib\matplotlib task.ipynb
# C:\data analyst course\november\15th,16th matplotlib\MATPLOTLIB.ipynb
# C:\data analyst course\november\15th,16th matplotlib\NIT-FSDS 5.30PM_ Course Summarization.xlsx
# C:\data analyst course\november\15th,16th matplotlib\REGULAR CLASS NOTES 5.30 AM.txt
# C:\data analyst course\november\15th,16th matplotlib\DataFrame_ Pandas\C4_ DATAFRAME.ipynb
# C:\data analyst course\november\15th,16th matplotlib\DataFrame_ Pandas\data.csv
# C:\data analyst course\november\15th,16th matplotlib\dt, time split\class example about raw vs clean.xlsx
# C:\data analyst course\november\15th,16th matplotlib\dt, time split\pandas DOCUMENTATAION.pdf
# C:\data analyst course\november\15th,16th matplotlib\dt, time split\TASK -- convert raw data - clean data.xlsx
# C:\data analyst course\november\15th,16th matplotlib\dt, time split\json,excel,html\Sample - Superstore_Orders.csv
# C:\data analyst course\november\18th- Kaggle, Dt , time split\MATPLOTLIB.html
# C:\data analyst course\november\18th- Kaggle, Dt , time split\NIT-FSDS 5.30PM_ Course Summarization.xlsx
# C:\data analyst course\november\18th- Kaggle, Dt , time split\Python operator, expresession Answer.pdf
# C:\data analyst course\november\18th- Kaggle, Dt , time split\Python operator, expresession question.pdf
# C:\data analyst course\november\18th- Kaggle, Dt , time split\PYTHON PRINT.pdf
# C:\data analyst course\november\18th- Kaggle, Dt , time split\REGULAR CLASS NOTES 5.30 AM.txt
# C:\data analyst course\november\18th- Kaggle, Dt , time split\TASK\class example about raw vs clean.xlsx
# C:\data analyst course\november\18th- Kaggle, Dt , time split\TASK\pandas DOCUMENTATAION.pdf
# C:\data analyst course\november\18th- Kaggle, Dt , time split\TASK\raw_data.xlsx
# C:\data analyst course\november\18th- Kaggle, Dt , time split\TASK\TASK -- convert raw data - clean data.xlsx
# C:\data analyst course\november\18th- Kaggle, Dt , time split\TASK\json,excel,html\Sample - Superstore_Orders.csv
# C:\data analyst course\november\19th - EDA theory\REGULAR CLASS NOTES 5.30 AM.txt
# C:\data analyst course\november\19th - EDA theory\19th, 20th -  EDA Theory\EDA INDEPTH - EXPLANATION.pptx
# C:\data analyst course\november\20th- EDA Practicle\clean_data.csv
# C:\data analyst course\november\20th- EDA Practicle\MATPLOTLIB.html
# C:\data analyst course\november\20th- EDA Practicle\NIT-FSDS 5.30PM_ Course Summarization.xlsx
# C:\data analyst course\november\20th- EDA Practicle\REGULAR CLASS NOTES 5.30 AM.txt
# C:\data analyst course\november\20th- EDA Practicle\EDA- Practicle\EDA INDEPTH - EXPLANATION.pptx
# C:\data analyst course\november\20th- EDA Practicle\EDA- Practicle\EDA LIVE CODING WORKSHOP .html
# C:\data analyst course\november\20th- EDA Practicle\EDA- Practicle\fetaure engineering steps.xlsx
# C:\data analyst course\november\20th- EDA Practicle\EDA- Practicle\Raw data TO  clean data conversion using python EDA.ipynb
# C:\data analyst course\november\20th- EDA Practicle\EDA- Practicle\Rawdata.xlsx
# C:\data analyst course\november\20th- EDA Practicle\EDA- Practicle\Test.csv
# C:\data analyst course\november\20th- EDA Practicle\EDA- Practicle\WORKSHOP ON EDA.pdf
# C:\data analyst course\november\20th- EDA Practicle\EDA- Practicle\~$Rawdata.xlsx
# C:\data analyst course\november\21st - Seaborn, Eda Practicle\EDA- HEALTHCARE DOMAIN\extensive-analysis-visualization-with-python.ipynb
# C:\data analyst course\november\21st - Seaborn, Eda Practicle\EDA- HEALTHCARE DOMAIN\heart.csv
# C:\data analyst course\november\21st - Seaborn, Eda Practicle\EDA- HEALTHCARE DOMAIN\Untitled-1.ipynb
# C:\data analyst course\november\21st - Seaborn, Eda Practicle\Seaborn - SPORT\FIFA.csv
# C:\data analyst course\november\21st - Seaborn, Eda Practicle\Seaborn - SPORT\seaborn-tutorial-for-beginners.ipynb
# C:\data analyst course\november\4th, 5th - Basic Python\1-BASIC PYTHON CODE TILL INPUT() FUNCTON - PART 1.ipynb
# C:\data analyst course\november\4th, 5th - Basic Python\Manipulating strings - Python Cheatsheet.pdf
# C:\data analyst course\november\4th, 5th - Basic Python\NIT-FSDS 5.30PM_ Course Summarization.xlsx
# C:\data analyst course\november\4th, 5th - Basic Python\PYTHON PRINT.pdf
# C:\data analyst course\november\4th, 5th - Basic Python\Python Strings Cheat Sheet _2.pdf
# C:\data analyst course\november\4th, 5th - Basic Python\REGULAR CLASS NOTES 5.30 AM.txt
# C:\data analyst course\november\6th,7th, 8th  - Numpy\00-NumPy-Crash-Course-Overview.ipynb
# C:\data analyst course\november\6th,7th, 8th  - Numpy\Matrix.pptx
# C:\data analyst course\november\6th,7th, 8th  - Numpy\NUMPY Complete DOCUMENTATION.pdf
# C:\data analyst course\november\6th,7th, 8th  - Numpy\NUMPY.pptx
# C:\data analyst course\november\6th,7th, 8th  - Numpy\NumPy_ the absolute basics for beginer.pdf
# C:\data analyst course\november\6th,7th, 8th  - Numpy\Numpy_Example_List - advance- PROJECT 1 - do not work.pdf

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st
# %matplotlib inline

sns.set(style="whitegrid")

# %%
# ignore warnings

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## import dataset

# %%
df=pd.read_csv(r"C:\data analyst course\november\21st - Seaborn, Eda Practicle\EDA- HEALTHCARE DOMAIN\heart.csv")

# %% [markdown]
# ## exploratory data analysis

# %%
#print the shape
print('the shape of dataset : ', df.shape)
# Out:
# the shape of dataset :  (303, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ## statistical properties of dataset

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# #### Important points to note
#
#
# - The above command `df.describe()` helps us to view the statistical properties of numerical variables. It excludes character variables.
#
# - If we want to view the statistical properties of character variables, we should run the following command -
#
#      `df.describe(include=['object'])`
#
# - If we want to view the statistical properties of all the variables, we should run the following command -
#
#      `df.describe(include='all')`

# %% [markdown]
# ### view column names

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# Univiarate analysis

# %% [markdown]
# check the number of unique values in the target variable

# %%
df['target'].nunique() # check the number of unique values in the target variable
# Out:
# 2

# %%
df['target'].unique() # view the unique values in the target variable
# Out:
# array([1, 0], dtype=int64)

# %%
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# So, there are 165 patients suffering from heart disease.
# 138 patients who do not have any heart disease.

# %% [markdown]
# ## visualize frequency distribution of target variable

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="target",hue="target", data=df)
plt.show()

# %% [markdown]
# frequency distribution of target variable wrt sex

# %%
df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="sex", hue="target",data=df)
plt.show()

# %%
ax=sns.catplot(x="target",col="sex",data=df,kind="count",height=5, aspect=1)

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(y="sex", hue="target",data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="target", hue="target",data=df, palette="Set2") # palette refers to diff colours
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="target", hue="target",data=df, facecolor=(0.1, 0.2, 0.5, 0),linewidth=8,edgecolor=sns.color_palette("dark",3))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 f,ax=plt.subplots(figsize=(8,6))
# ----> 2 ax=sns.countplot(x="target", hue="target",data=df, facecolor=(0.1, 0.2, 0.5, 0),linewidth=8,edgecolor=sns.color_palette("dark",3))
#       3 plt.show()
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\seaborn\categorical.py:2675, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2671     p.plot_data[count_axis] /= len(p.plot_data) / denom
#    2673 aggregator = EstimateAggregator("sum", errorbar=None)
# -> 2675 p.plot_bars(
#    2676     aggregator=aggregator,
#    2677     dodge=dodge,
#    2678     width=width,
#    2679     gap=gap,
#    2680     color=color,
#    2681     fill=fill,
#    2682     capsize=0,
#    2683     err_kws={},
#    2684     plot_kws=kwargs,
#    2685 )
#    2687 p._add_axis_labels(ax)
#    2688 p._adjust_cat_axis(ax, axis=p.orient)
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\seaborn\categorical.py:1324, in _CategoricalPlotter.plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1318         self.plot_errorbars(
#    1319             ax, agg_data, capsize,
#    1320             {"color": ".26" if fill else main_color, **err_kws}
#    1321         )
#    1323 legend_artist = _get_patch_legend_artist(fill)
# -> 1324 self._configure_legend(ax, legend_artist, plot_kws)
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\seaborn\categorical.py:427, in _CategoricalPlotter._configure_legend(self, ax, func, common_kws, semantic_kws)
#     425     show_legend = bool(self.legend)
#     426 if show_legend:
# --> 427     self.add_legend_data(ax, func, common_kws, semantic_kws=semantic_kws)
#     428     handles, _ = ax.get_legend_handles_labels()
#     429     if handles:
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\seaborn\_base.py:1267, in VectorPlotter.add_legend_data(self, ax, func, common_kws, attrs, semantic_kws)
#    1265     if attr in kws:
#    1266         level_kws[attr] = kws[attr]
# -> 1267 artist = func(label=label, **{"color": ".2", **common_kws, **level_kws})
#    1268 if _version_predates(mpl, "3.5.0"):
#    1269     if isinstance(artist, mpl.lines.Line2D):
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\seaborn\utils.py:895, in _get_patch_legend_artist.<locals>.legend_artist(**kws)
#     892         kws["edgecolor"] = color
#     893         kws["facecolor"] = "none"
# --> 895 return mpl.patches.Rectangle((0, 0), 0, 0, **kws)
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\matplotlib\patches.py:718, in Rectangle.__init__(self, xy, width, height, angle, rotation_point, **kwargs)
#     694 @_docstring.dedent_interpd
#     695 def __init__(self, xy, width, height, *,
#     696              angle=0.0, rotation_point='xy', **kwargs):
#     697     """
#     698     Parameters
#     699     ----------
#    (...)
#     716         %(Patch:kwdoc)s
#     717     """
# --> 718     super().__init__(**kwargs)
#     719     self._x0 = xy[0]
#     720     self._y0 = xy[1]
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\matplotlib\patches.py:83, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      81     self.set_color(color)
#      82 else:
# ---> 83     self.set_edgecolor(edgecolor)
#      84     self.set_facecolor(facecolor)
#      86 self._linewidth = 0
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\matplotlib\patches.py:338, in Patch.set_edgecolor(self, color)
#     330 """
#     331 Set the patch edge color.
#     332
#    (...)
#     335 color : color or None
#     336 """
#     337 self._original_edgecolor = color
# --> 338 self._set_edgecolor(color)
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\matplotlib\patches.py:324, in Patch._set_edgecolor(self, color)
#     321         color = 'none'
#     322         set_hatch_color = False
# --> 324 self._edgecolor = colors.to_rgba(color, self._alpha)
#     325 if set_hatch_color:
#     326     self._hatch_color = self._edgecolor
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\matplotlib\colors.py:302, in to_rgba(c, alpha)
#     300     rgba = None
#     301 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 302     rgba = _to_rgba_no_colorcycle(c, alpha)
#     303     try:
#     304         _colors_full_map.cache[c, alpha] = rgba
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\matplotlib\colors.py:397, in _to_rgba_no_colorcycle(c, alpha)
#     393     raise ValueError("RGBA sequence should have length 3 or 4")
#     394 if not all(isinstance(x, Real) for x in c):
#     395     # Checks that don't work: `map(float, ...)`, `np.array(..., float)` and
#     396     # `np.array(...).astype(float)` would all convert "0.5" to 0.5.
# --> 397     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     398 # Return a tuple to prevent the cached value from being modified.
#     399 c = tuple(map(float, c))
#
# ValueError: Invalid RGBA argument: [(0.0, 0.10980392156862745, 0.4980392156862745), (0.6941176470588235, 0.25098039215686274, 0.050980392156862744), (0.07058823529411765, 0.44313725490196076, 0.10980392156862745)]

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", hue="fbs", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", hue="exang", data=df)
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
correlation=df.corr()

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %% [markdown]
# ## analysis of target and cp variable

# %% [markdown]
# - We can see that the `cp` and `thalach` variables are mildly positively correlated with `target` variable. So, I will analyze the interaction between these features and `target` variable.

# %%
df['cp'].nunique()
# Out:
# 4

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="cp",hue='cp',data=df)
plt.show()

# %% [markdown]
# frequency distribution of target variable wrt  cp

# %%
df.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %% [markdown]
# we can visualize the value counts of the cp variable wrt target as follows:

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="cp",hue="target",data=df) # in every cp there is target(0,1).so, we take hue = target
plt.show()

# %% [markdown]
# alternatively we can visualize the same info for separate cp values

# %%
ax=sns.catplot(x="target",col="cp",hue="target",data=df,kind="count",height=8,aspect=1)

# %% [markdown]
# now cp values wrt target

# %%
ax=sns.catplot(x="cp",col="target",hue="cp",data=df,kind="count",height=8,aspect=1)

# %% [markdown]
# ## analysis of target and thalch variable

# %%
df['thalach'].nunique()
# Out:
# 91

# %% [markdown]
# visualize the frequency distribution of thalach variable

# %%
f,ax=plt.subplots(figsize=(8,6))
x=df['thalach']
ax=sns.distplot(x,bins=10)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
x=df['thalach']
ax=sns.histplot(x,kde=True,bins=10,ax=ax)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
x=df['thalach']
x=pd.Series(x,name="thalach variable")
ax=sns.distplot(x,bins=10)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
x=df['thalach']
ax=sns.distplot(x,bins=10,vertical=True)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalach']
x=pd.Series(x,name="thalach variable")
ax=sns.kdeplot(x)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalach']
x=pd.Series(x,name="thalach variable")
ax=sns.kdeplot(x, shade=True, color='r') # shading the colour under the curve
plt.show()

# %% [markdown]
# ## Histogram

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalach']
ax=sns.distplot(x,kde=False, rug=True, bins=10)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.stripplot(x="target", y="thalach", data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.stripplot(x="target",y="thalach", data=df, jitter=0.01)
plt.show()

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.8.4'

# %% [markdown]
# visualize distribution of thalach variable wrt target with boxplot

# %%
f, ax=plt.subplots(figsize=(8,6))
sns.boxplot(x="target", y="thalach",hue="target", data=df)
plt.show()

# %% [markdown]
# ## multivariate analysis

# %% [markdown]
# ### HEAT MAP

# %%
plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of heart disease Dataset')
a=sns.heatmap(correlation, square=True,annot=True, fmt='.2f',linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)
plt.show()

# %% [markdown]
# ## pairplot

# %%
num_var=['age','trestbps','chol','thalach','oldpeak','target']
sns.pairplot(df[num_var],kind='scatter', diag_kind='hist')
plt.show()

# %% [markdown]
# ## analysis of age and other variables
# check the number of unique values in age variable

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['age']
ax=sns.distplot(x, bins=10)
plt.show()

# %% [markdown]
# ## analyze age and target variable
# visualize frequency distribution of age variable wrt target

# %%
f, ax=plt.subplots(figsize=(8,6))
sns.stripplot(x="target", y="age",hue="target", data=df)
plt.show()

# %% [markdown]
# ### visualize distribution of age variable wrt target with boxplot

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x="target", y="age",hue="target", data=df)
plt.show()

# %% [markdown]
# ### analyze age and trestbps variable

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.scatterplot(x="age", y="trestbps", data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.regplot(x="age", y="trestbps", data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.scatterplot(x="age", y="chol", data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.regplot(x="age", y="chol", data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.scatterplot(x="chol", y="thalach", data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.regplot(x="chol", y="thalach", data=df)
plt.show()

# %% [markdown]
# ## Dealing with missing values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ## check with ASSERT statement

# %%
assert pd.notnull(df).all().all()

# %%
assert(df>=0).all().all()

# %% [markdown]
# ## Outlier detection

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.boxplot(x=df['age'])
plt.show()

# %%
df['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.boxplot(x=df['trestbps'])
plt.show()

# %%
df['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.boxplot(x=df['chol'])
plt.show()

# %%
df['thalach'].describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.boxplot(x=df['thalach'])
plt.show()

# %%
df['oldpeak'].describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.boxplot(x=df['oldpeak'])
plt.show()
